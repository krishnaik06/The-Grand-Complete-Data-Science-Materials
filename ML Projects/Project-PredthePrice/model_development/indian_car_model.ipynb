# %%
import pandas as pd
from modelprocessing.functions import getBestModel
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
import numpy as np
from xgboost import XGBRegressor
import skops.io as sio
import seaborn as sns

# %%
df = pd.read_csv('/home/anuraaga/Documents/Projects/pricePredictor/dataset/dataset_car/indian_car.csv', index_col=0)
df
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [815 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
df.describe().T
# Out:
#             count           mean            std      min       25%       50%  \
# year        815.0    2012.442945       4.005079   1995.0    2010.0    2013.0
# Price       815.0  401793.338650  381588.817401  30000.0  175000.0  299999.0
# kms_driven  815.0   46277.096933   34318.459638      0.0   27000.0   41000.0
#
#                  75%        max
# year          2015.0     2019.0
# Price       490000.0  3100000.0
# kms_driven   56879.0   400000.0

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
df=df[df['Price']<6000000]

# %%
X = df.drop('Price', axis=1)
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
ohe = OneHotEncoder(drop='first', sparse_output=False, dtype=np.int32)
ohe.fit(X[['name', 'company', 'fuel_type']])
# Out:
# OneHotEncoder(drop='first', dtype=<class 'numpy.int32'>, sparse_output=False)

# %%
column_transformer = make_column_transformer((OneHotEncoder(categories=ohe.categories_), ['name', 'company', 'fuel_type']),
                                             remainder='passthrough')

# %%
getBestModel(X_train, X_test, y_train, y_test, column_transformer)
# Out:
# Fitting Models:  42%|████▏     | 5/12 [00:01<00:01,  5.86model/s]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Fitting Models:  75%|███████▌  | 9/12 [00:01<00:00, 12.29model/s]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 597229486364.2832, tolerance: 9335347827.42903
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.28model/s]
#                         model  train score  r2 score
# 4                XGBRegressor     0.976628  0.890655
# 0       RandomForestRegressor     0.941681  0.881656
# 1         ExtraTreesRegressor     0.999969  0.876655
# 10                      Lasso     0.945009  0.855029
# 5            LinearRegression     0.761706  0.818901
# 2   GradientBoostingRegressor     0.865665  0.799586
# 11                 ElasticNet     0.209838  0.164670
# 3           AdaBoostRegressor     0.285221  0.107689
# 9                       Ridge     0.141255  0.087567
# 8                       NuSVR    -0.030663 -0.042852
# 7                         SVR    -0.068178 -0.084018
# 6                   LinearSVR    -0.886127 -0.919814

# %%
from modelprocessing.functions import getBestState
getBestState(X, y, 0.2, column_transformer)
# Out:
# getting best state:   0%|          | 0/100 [00:00<?, ?state/s]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251189494045.56104, tolerance: 9853603658.670992
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.77model/s]
# getting best state:   1%|          | 1/100 [00:01<03:02,  1.84s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 440500704087.2915, tolerance: 9338607722.320433
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.55model/s]
# getting best state:   2%|▏         | 2/100 [00:03<02:46,  1.70s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586582798900.7842, tolerance: 9786104406.095747
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.25model/s]
# getting best state:   3%|▎         | 3/100 [00:05<02:42,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 421086152507.04297, tolerance: 9603384774.67775
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.38model/s]
# getting best state:   4%|▍         | 4/100 [00:06<02:39,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 597229486364.2832, tolerance: 9335347827.42903
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.20model/s]
# getting best state:   5%|▌         | 5/100 [00:08<02:38,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 524761510677.74854, tolerance: 9304483091.48171
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.44model/s]
# getting best state:   6%|▌         | 6/100 [00:10<02:34,  1.65s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 721821327979.2405, tolerance: 9207322404.732183
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.14model/s]
# getting best state:   7%|▋         | 7/100 [00:11<02:34,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 691675552976.7422, tolerance: 10154752377.752699
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.18model/s]
# getting best state:   8%|▊         | 8/100 [00:13<02:33,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 681975934556.5752, tolerance: 9173841493.848156
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.36model/s]
# getting best state:   9%|▉         | 9/100 [00:15<02:30,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 915766444437.771, tolerance: 10489837725.846184
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.46model/s]
# getting best state:  10%|█         | 10/100 [00:16<02:27,  1.64s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 909136897143.6675, tolerance: 9741662035.103703
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.30model/s]
# getting best state:  11%|█         | 11/100 [00:18<02:26,  1.65s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 738322949917.6753, tolerance: 9188566065.070505
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.26model/s]
# getting best state:  12%|█▏        | 12/100 [00:19<02:25,  1.65s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 803145942591.9187, tolerance: 9919310665.878683
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.93model/s]
# getting best state:  13%|█▎        | 13/100 [00:21<02:25,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1001604544864.5039, tolerance: 9293449071.833866
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.02model/s]
# getting best state:  14%|█▍        | 14/100 [00:23<02:25,  1.69s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 629539276003.5347, tolerance: 10694889340.820026
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.92model/s]
# getting best state:  15%|█▌        | 15/100 [00:25<02:24,  1.70s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 734527959117.2046, tolerance: 10275353678.507572
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.08model/s]
# getting best state:  16%|█▌        | 16/100 [00:26<02:23,  1.70s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318714682061.6157, tolerance: 8810941109.224598
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.83model/s]
# getting best state:  17%|█▋        | 17/100 [00:28<02:22,  1.72s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 475370398144.68896, tolerance: 8815257109.911163
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.15model/s]
# getting best state:  18%|█▊        | 18/100 [00:30<02:20,  1.71s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 455167544307.2744, tolerance: 9840363252.599417
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.35model/s]
# getting best state:  19%|█▉        | 19/100 [00:31<02:16,  1.69s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 703382587851.3984, tolerance: 9791632043.081219
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.30model/s]
# getting best state:  20%|██        | 20/100 [00:33<02:14,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 743631276878.7537, tolerance: 9395670939.287727
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.87model/s]
# getting best state:  21%|██        | 21/100 [00:35<02:14,  1.70s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 521773286078.4531, tolerance: 8803850812.627802
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.31model/s]
# getting best state:  22%|██▏       | 22/100 [00:36<02:11,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 836027729311.958, tolerance: 10354775779.600342
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.40model/s]
# getting best state:  23%|██▎       | 23/100 [00:38<02:08,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 572244628739.3364, tolerance: 9550642839.779316
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.34model/s]
# getting best state:  24%|██▍       | 24/100 [00:40<02:06,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 653997545543.9453, tolerance: 8096075627.181105
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.40model/s]
# getting best state:  25%|██▌       | 25/100 [00:41<02:03,  1.65s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 570714555058.2905, tolerance: 9525950841.660538
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.21model/s]
# getting best state:  26%|██▌       | 26/100 [00:43<02:02,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 614321027692.0337, tolerance: 8665291572.71682
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.26model/s]
# getting best state:  27%|██▋       | 27/100 [00:45<02:00,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 608199523767.4028, tolerance: 10213661198.632164
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.14model/s]
# getting best state:  28%|██▊       | 28/100 [00:46<01:59,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 779156976371.0847, tolerance: 9747430976.53626
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.31model/s]
# getting best state:  29%|██▉       | 29/100 [00:48<01:57,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 588486703232.2031, tolerance: 8763944862.690016
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.16model/s]
# getting best state:  30%|███       | 30/100 [00:50<01:56,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 476136765740.7529, tolerance: 7996390688.139472
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.23model/s]
# getting best state:  31%|███       | 31/100 [00:51<01:54,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 678719653561.2036, tolerance: 8843929347.855087
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.31model/s]
# getting best state:  32%|███▏      | 32/100 [00:53<01:52,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 932030068460.0935, tolerance: 10069907147.819006
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.13model/s]
# getting best state:  33%|███▎      | 33/100 [00:55<01:51,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 480553994263.83936, tolerance: 9401258755.684761
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.06model/s]
# getting best state:  34%|███▍      | 34/100 [00:56<01:50,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 296507895634.5039, tolerance: 8951949243.100494
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.53model/s]
# getting best state:  35%|███▌      | 35/100 [00:58<01:47,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 675421472322.7168, tolerance: 9397990236.055695
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.33model/s]
# getting best state:  36%|███▌      | 36/100 [01:00<01:45,  1.65s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520880546750.60254, tolerance: 10166962057.755363
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.20model/s]
# getting best state:  37%|███▋      | 37/100 [01:01<01:44,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 793526662848.3062, tolerance: 9718048492.524338
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.10model/s]
# getting best state:  38%|███▊      | 38/100 [01:03<01:43,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 613017104186.0908, tolerance: 10418552482.803688
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.37model/s]
# getting best state:  39%|███▉      | 39/100 [01:05<01:41,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 676932827588.4417, tolerance: 10266110387.794218
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.92model/s]
# getting best state:  40%|████      | 40/100 [01:06<01:40,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 556579391201.6382, tolerance: 9713462602.467402
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.24model/s]
# getting best state:  41%|████      | 41/100 [01:08<01:38,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 702111879160.4155, tolerance: 8908926144.888987
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.21model/s]
# getting best state:  42%|████▏     | 42/100 [01:10<01:37,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 662412234049.7861, tolerance: 8486400679.924483
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.68model/s]
# getting best state:  43%|████▎     | 43/100 [01:12<01:37,  1.71s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 661278388443.1528, tolerance: 9231982737.04434
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.17model/s]
# getting best state:  44%|████▍     | 44/100 [01:13<01:35,  1.70s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 685224850095.4902, tolerance: 9872329764.507513
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.02model/s]
# getting best state:  45%|████▌     | 45/100 [01:15<01:33,  1.71s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 715203834302.9336, tolerance: 8880272922.493874
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.50model/s]
# getting best state:  46%|████▌     | 46/100 [01:17<01:30,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 337343931119.73486, tolerance: 9008907873.03447
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.53model/s]
# getting best state:  47%|████▋     | 47/100 [01:18<01:27,  1.65s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 345230910935.73535, tolerance: 8218006369.060385
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.10model/s]
# getting best state:  48%|████▊     | 48/100 [01:20<01:26,  1.67s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.16model/s]
# getting best state:  84%|████████▍ | 84/100 [02:21<00:27,  1.71s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 679131021470.4136, tolerance: 10156556602.83313
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.07model/s]
# getting best state:  85%|████████▌ | 85/100 [02:23<00:25,  1.71s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 800730398511.0063, tolerance: 9854933828.467585
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.79model/s]
# getting best state:  86%|████████▌ | 86/100 [02:24<00:24,  1.73s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 753183246439.501, tolerance: 9580585507.520247
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.84model/s]
# getting best state:  87%|████████▋ | 87/100 [02:26<00:22,  1.74s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1138405071116.0383, tolerance: 10435328829.302622
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.94model/s]
# getting best state:  88%|████████▊ | 88/100 [02:28<00:20,  1.74s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 844838146895.7305, tolerance: 9276673138.57242
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:02<00:00,  5.14model/s]
# getting best state:  89%|████████▉ | 89/100 [02:30<00:21,  1.92s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 475884929754.00635, tolerance: 9590913055.949467
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.36model/s]
# getting best state:  90%|█████████ | 90/100 [02:32<00:18,  1.83s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 599615676397.9307, tolerance: 9347089897.576988
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.89model/s]
# getting best state:  91%|█████████ | 91/100 [02:34<00:16,  1.81s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 352522268008.147, tolerance: 10201662650.828766
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.39model/s]
# getting best state:  92%|█████████▏| 92/100 [02:35<00:14,  1.75s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 527199373344.25, tolerance: 9347612954.083279
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.44model/s]
# getting best state:  93%|█████████▎| 93/100 [02:37<00:11,  1.71s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586206930561.9756, tolerance: 8755075434.456842
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.42model/s]
# getting best state:  94%|█████████▍| 94/100 [02:38<00:10,  1.69s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1062622210713.1482, tolerance: 8222274459.726241
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.25model/s]
# getting best state:  95%|█████████▌| 95/100 [02:40<00:08,  1.68s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 498990330149.6304, tolerance: 9210156853.177715
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.47model/s]
# getting best state:  96%|█████████▌| 96/100 [02:42<00:06,  1.66s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 666957749975.2988, tolerance: 9750444232.772436
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.45model/s]
# getting best state:  97%|█████████▋| 97/100 [02:44<00:05,  1.72s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 776884810842.8408, tolerance: 10370497855.221075
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.01model/s]
# getting best state:  98%|█████████▊| 98/100 [02:45<00:03,  1.72s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 804174226282.9502, tolerance: 9497698305.229856
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  7.07model/s]
# getting best state:  99%|█████████▉| 99/100 [02:47<00:01,  1.71s/state]/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 481971314045.08057, tolerance: 9434914739.413404
#   model = cd_fast.sparse_enet_coordinate_descent(
# Fitting Models: 100%|██████████| 12/12 [00:01<00:00,  6.87model/s]
# getting best state: 100%|██████████| 100/100 [02:49<00:00,  1.69s/state]
# 4

# %%
df.to_csv('/home/anuraaga/Documents/DataCodes/Projects/pricePredictor/dataset/dataset_car/indian_car.csv')

# %%
# run it in google colab

# xg = XGBRegressor(tree_method='gpu_hist', predictor='gpu_predictor', device='cuda', verbosity=0)
# param_grid = {
#     'booster': ['gbtree', 'gblinear', 'dart'],
#     'max_depth': [3, 5, 7],
#     'learning_rate': [0.01, 0.1, 0.2]
# }
# grid = GridSearchCV(xg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=10)
# pipetest = make_pipeline(column_transformer,  grid)
# pipetest.fit(X_train, y_train)
# print(pipetest.named_steps['gridsearchcv'].best_params_)



# xg = XGBRegressor(booster= 'dart',
#                   learning_rate= 0.2,
#                   max_depth= 7,
#                   verbosity=0,
#                   tree_method='gpu_hist',
#                   predictor='gpu_predictor',
#                   device='cuda')
# pipe = make_pipeline(column_transformer, xg)
# pipe.fit(X_train, y_train)

# %%
pipe = sio.load('models/indiancarmodel_pipeline.skops', trusted=True)
# Out:
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [15:21:36] WARNING: /workspace/src/gbm/gbtree.cc:360:
#   Loading from a raw memory buffer (like pickle in Python, RDS in R) on a CPU-only
#   machine. Consider using `save_model/load_model` instead. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.  Changing `tree_method` to `hist`.
#   warnings.warn(smsg, UserWarning)
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [15:21:36] WARNING: /workspace/src/gbm/gbtree.cc:385: Changing updater from `grow_gpu_hist` to `grow_quantile_histmaker`.
#   warnings.warn(smsg, UserWarning)
# /home/anuraaga/Documents/DataCodes/Projects/pricePredictor/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [15:21:36] WARNING: /workspace/src/context.cc:44: No visible GPU is found, setting device to CPU.
#   warnings.warn(smsg, UserWarning)

# %%
pipe.score(X_train, y_train)
# Out:
# 0.9692940120070288

# %%
pipe.score(X_test, y_test)
# Out:
# 0.890513537146146
