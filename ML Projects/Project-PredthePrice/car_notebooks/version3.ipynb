# %%
# import packages
import pandas as pd
import pickle

# %%
df = pd.read_pickle('/home/anuraaga/Documents/Projects/pricePredictor/dataset/dataset_car/autos_v2.pkl')

# %%
df
# Out:
#                                    name   abtest vehicleType  \
# 0                             Golf 3 16     test      Others
# 1                     Audi A5 Sportback     test       Coupe
# 2                   Jeep Grand Cherokee     test         Suv
# 3                              GOLF 4 1     test     Compact
# 4                        Skoda Fabia 14     test     Compact
# ...                                 ...      ...         ...
# 360729           Sonstigeautos Suche t4     test      Others
# 360730  Smart smart leistungssteigerung     test      Cabrio
# 360731           Volkswagen Multivan T4     test         Bus
# 360732                    VW Golf Kombi     test       Combi
# 360733       BMW M135i vollausgestattet  control   Limousine
#
#         yearOfRegistration    gearbox  kilometer  monthOfRegistration  \
# 0                     1993    manuell     150000                    0
# 1                     2011    manuell     125000                    5
# ...

# %%
df.isna().sum()
# Out:
# name                       0
# abtest                     0
# vehicleType                0
# yearOfRegistration         0
# gearbox                19223
# kilometer                  0
# monthOfRegistration        0
# fuelType               32922
# brand                      0
# notRepairedDamage      70076
# price(inr)                 0
# dtype: int64

# %%
df['gearbox'].value_counts()
# Out:
# gearbox
# manuell      266895
# automatik     74616
# Name: count, dtype: int64

# %%
df['gearbox'].fillna(df['gearbox'].mode()[0], inplace=True)

# %%
df['gearbox'].replace({'manuell':'manual', 'automatik':'automatic'}, inplace=True)

# %%
df['gearbox'].value_counts()
# Out:
# gearbox
# manual       286118
# automatic     74616
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# name                       0
# abtest                     0
# vehicleType                0
# yearOfRegistration         0
# gearbox                    0
# kilometer                  0
# monthOfRegistration        0
# fuelType               32922
# brand                      0
# notRepairedDamage      70076
# price(inr)                 0
# dtype: int64

# %%
df
# Out:
#                                    name   abtest vehicleType  \
# 0                             Golf 3 16     test      Others
# 1                     Audi A5 Sportback     test       Coupe
# 2                   Jeep Grand Cherokee     test         Suv
# 3                              GOLF 4 1     test     Compact
# 4                        Skoda Fabia 14     test     Compact
# ...                                 ...      ...         ...
# 360729           Sonstigeautos Suche t4     test      Others
# 360730  Smart smart leistungssteigerung     test      Cabrio
# 360731           Volkswagen Multivan T4     test         Bus
# 360732                    VW Golf Kombi     test       Combi
# 360733       BMW M135i vollausgestattet  control   Limousine
#
#         yearOfRegistration    gearbox  kilometer  monthOfRegistration  \
# 0                     1993     manual     150000                    0
# 1                     2011     manual     125000                    5
# ...

# %%
df['fuelType'].fillna('andere', inplace=True)

# %%
uniqueFuelType = df['fuelType'].unique()

# %%
from deep_translator import GoogleTranslator
def translateClass(uniquevalues):
    translator = GoogleTranslator(target='en')
    rename = dict()
    for x in uniquevalues:
        rename[x] = translator.translate(x)
    print(rename)
    return rename

# %%
replaceFuelType = translateClass(uniquevalues=uniqueFuelType)
# Out:
# {'benzin': 'petrol', 'diesel': 'diesel', 'andere': 'Others', 'lpg': 'lpg', 'hybrid': 'hybrid', 'cng': 'cng', 'elektro': 'electro'}

# %%
df['fuelType'].replace(replaceFuelType, inplace=True)
# df['fuelType'].replace({'Others':'other'}, inplace=True)

# %%
df['fuelType'].value_counts()
# Out:
# fuelType
# Petrol      218428
# Diesel      102977
# Others       33128
# Lpg           5265
# Cng            559
# Hybrid         274
# Electric       103
# Name: count, dtype: int64

# %%
df['fuelType'] = df['fuelType'].str.capitalize()

# %%
df['fuelType'].replace({'Electro':'Electric'}, inplace=True)

# %%
df.isna().sum()
# Out:
# name                       0
# abtest                     0
# vehicleType                0
# yearOfRegistration         0
# gearbox                    0
# kilometer                  0
# monthOfRegistration        0
# fuelType                   0
# brand                      0
# notRepairedDamage      70076
# price(inr)                 0
# dtype: int64

# %%
df
# Out:
#                                    name   abtest vehicleType  \
# 0                             Golf 3 16     test      Others
# 1                     Audi A5 Sportback     test       Coupe
# 2                   Jeep Grand Cherokee     test         Suv
# 3                              GOLF 4 1     test     Compact
# 4                        Skoda Fabia 14     test     Compact
# ...                                 ...      ...         ...
# 360729           Sonstigeautos Suche t4     test      Others
# 360730  Smart smart leistungssteigerung     test      Cabrio
# 360731           Volkswagen Multivan T4     test         Bus
# 360732                    VW Golf Kombi     test       Combi
# 360733       BMW M135i vollausgestattet  control   Limousine
#
#         yearOfRegistration    gearbox  kilometer  monthOfRegistration  \
# 0                     1993     manual     150000                    0
# 1                     2011     manual     125000                    5
# ...

# %%
df['notRepairedDamage'].fillna('nein', inplace=True)

# %%
df['notRepairedDamage'].replace({'nein':False, 'ja':True}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360734 entries, 0 to 360733
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 360734 non-null  object
#  1   abtest               360734 non-null  object
#  2   vehicleType          360734 non-null  object
#  3   yearOfRegistration   360734 non-null  int64
#  4   gearbox              360734 non-null  object
#  5   kilometer            360734 non-null  int64
#  6   monthOfRegistration  360734 non-null  int64
#  7   fuelType             360734 non-null  object
#  8   brand                360734 non-null  object
#  9   notRepairedDamage    360734 non-null  bool
#  10  price(inr)           360734 non-null  int64
# dtypes: bool(1), int64(4), object(6)
# memory usage: 27.9+ MB

# %%
df
# Out:
#                                    name   abtest vehicleType  \
# 0                             Golf 3 16     test      Others
# 1                     Audi A5 Sportback     test       Coupe
# 2                   Jeep Grand Cherokee     test         Suv
# 3                              GOLF 4 1     test     Compact
# 4                        Skoda Fabia 14     test     Compact
# ...                                 ...      ...         ...
# 360729           Sonstigeautos Suche t4     test      Others
# 360730  Smart smart leistungssteigerung     test      Cabrio
# 360731           Volkswagen Multivan T4     test         Bus
# 360732                    VW Golf Kombi     test       Combi
# 360733       BMW M135i vollausgestattet  control   Limousine
#
#         yearOfRegistration    gearbox  kilometer  monthOfRegistration  \
# 0                     1993     Manual     150000                    0
# 1                     2011     Manual     125000                    5
# ...

# %%
df['gearbox'] = df['gearbox'].str.capitalize()

# %%
df.isna().sum()
# Out:
# name                   0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# price(inr)             0
# dtype: int64

# %%
pickle.dump(df, open('/home/anuraaga/Documents/Projects/pricePredictor/dataset/dataset_car/autos_v3.pkl', 'wb'))
