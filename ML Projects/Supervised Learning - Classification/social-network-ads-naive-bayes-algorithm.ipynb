# %% [markdown]
# ## Implementation of Naive Bayes Algorithm (Product Purchased or Not)

# %% [markdown]
# #### 1.Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 2.Importing Dataset

# %%
dataset = pd.read_csv('/kaggle/input/social-network-ads/Social_Network_Ads.csv')

# %%
dataset.isnull().sum()

# %%
dataset.shape

# %% [markdown]
# #### 3.Data Preprocessing

# %%
dataset.columns

# %%
dataset['Purchased'].value_counts().plot(kind="pie", autopct="%1.1f%%")

# %%
sns.set(style="dark")

# Histogram for Insulin
plt.figure(figsize=(9,4))
plt.subplot(1, 2, 1)
sns.histplot(data=dataset, x='EstimatedSalary',bins=5, kde=True)
plt.title('EstimatedSalary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')

# %% [markdown]
# #### 4.Seprating Features and Dependant Variable

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
from mpl_toolkits.mplot3d import Axes3D  # Import the 3D plotting toolkit

# Assuming you have your data loaded as X and y
# X should have shape (400, 2), and y should have shape (400,)

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Extract the two columns of X
X1 = X[:, 0]
X2 = X[:, 1]

# Plot the 3D scatter plot
ax.scatter(X1, X2, y, c='blue', marker='o')

# Set labels for the axes
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Target (y)')

# Set a title
plt.title('3D Scatter Plot of X vs. y')

# Display the plot
plt.show()

# %%
X

# %% [markdown]
# #### 5.Spliting Train and Test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### 6.Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
X_train_scaled[:5,:]

# %% [markdown]
# #### 7.Model Building and Traning

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,y_train)

# %% [markdown]
# #### 8.Predicting Results

# %%
y_pred = nb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay
print("Accuracy Score of Model : ",accuracy_score(y_test,y_pred)*100)

# %%
data = pd.DataFrame({'Actual':y_test,"Predicted":y_pred})
data

# %%
print(nb.predict(sc.transform([[30,87000]])))

# %%
dataset

# %%
labels = [0,1]
cm = confusion_matrix(y_test, y_pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();
cm
